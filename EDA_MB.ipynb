# %%
import pandas as pd
from matplotlib import pyplot as plt
from numpy import polyfit

# %%
df = pd.read_csv("data/statcast_pitch_swing_data_20240402_20240630.csv")
df.shape
# Out:
# (346250, 94)

# %%
df = df.dropna(subset=['bat_speed', 'swing_length', 'launch_speed'])
df.shape
print(df.head())
# Out:
#      pitch_type game_date  release_speed  release_pos_x  release_pos_z  \
# 3631         FF  4/3/2024           96.7          -2.49           5.03
# 3637         FC  4/3/2024           95.9          -1.12           5.91
# 3639         FC  4/3/2024           95.4          -0.98           6.02
# 3640         SL  4/3/2024           91.2          -1.63           6.00
# 3641         FS  4/3/2024           89.8          -2.41           5.37
#
#           player_name  batter  pitcher events description  ...  \
# 3631  Ramírez, Harold  623912   543135    NaN        foul  ...
# 3637   Fermin, Freddy  666023   669203    NaN        foul  ...
# 3639   Fermin, Freddy  666023   669203    NaN        foul  ...
# 3640  Estrada, Thairo  642731   607192    NaN        foul  ...
# 3641  Ramírez, Harold  623912   543135    NaN        foul  ...
#
#       post_home_score  post_bat_score  post_fld_score  if_fielding_alignment  \
# 3631                0               0               1               Standard
# 3637                0               2               0               Standard
# 3639                0               2               0               Standard
# 3640                4               3               4               Standard
# 3641                0               0               1               Standard
#
#       of_fielding_alignment spin_axis delta_home_win_exp delta_run_exp  \
# 3631               Standard     236.0                0.0         0.000
# 3637               Standard     183.0                0.0         0.000
# 3639               Standard     197.0                0.0         0.000
# 3640               Standard     156.0                0.0         0.000
# 3641               Standard     246.0                0.0        -0.015
#
#       bat_speed swing_length
# 3631  68.912017      6.29951
# 3637  69.626229      7.35832
# 3639  67.891985      6.40032
# 3640  25.589201      5.76072
# 3641  76.893083      7.88750
#
# [5 rows x 94 columns]

# %%
fig = plt.figure()
plt.scatter(df["bat_speed"], df["swing_length"])
plt.xlabel("Bat Speed")
plt.ylabel("Swing Length")
plt.title("Bat Speed vs Swing Length")
plt.show()

# %%
fig = plt.figure()
plt.grid(True)
plt.scatter(df["bat_speed"], df["launch_speed"], c='blue', s=10, alpha=0.5)
plt.xlabel("Bat Speed")
plt.ylabel("Exit Velo")
plt.title("Bat Speed vs Exit Velo")
m, b = polyfit(df["bat_speed"], df["launch_speed"], 1)
plt.plot(df["bat_speed"], m * df["bat_speed"] + b, color='red')
plt.show()

# %%
correlation = df["bat_speed"].corr(df["launch_speed"])
print(f"Correlation between Bat Speed and Exit Velo: {correlation:.2f}")
# Out:
# Correlation between Bat Speed and Exit Velo: 0.35

# %%
fig = plt.figure()
plt.grid(True)
plt.scatter(df["bat_speed"], df["estimated_woba_using_speedangle"], c='blue', s=10, alpha=0.5)
plt.xlabel("Bat Speed")
plt.ylabel("xWoba")
plt.title("Bat Speed vs xWoba")
plt.show()

# %%
correlation = df["bat_speed"].corr(df["estimated_woba_using_speedangle"])
print(f"Correlation between Bat Speed and xWoba: {correlation:.2f}")
# Out:
# Correlation between Bat Speed and xWoba: 0.17
